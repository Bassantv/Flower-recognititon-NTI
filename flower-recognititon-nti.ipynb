# %% [markdown]
# # ***DATA LOADING***

# %%
from keras import Sequential
from keras.layers import Dense, Input,Flatten
from keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
import numpy as np

# %%
data=ImageDataGenerator(
    rescale=1./255.,
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest',
     validation_split=0.2)

# %%
train=data.flow_from_directory(
    '/kaggle/input/flowers-recognition/flowers',
    target_size=(240,240),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
    )
# Out:
# Found 3457 images belonging to 5 classes.

# %%
vaild=data.flow_from_directory(
    '/kaggle/input/flowers-recognition/flowers',
    target_size=(240,240),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
    )
# Out:
# Found 860 images belonging to 5 classes.

# %% [markdown]
# # ***MODEL IMPLENETATION CNN***

# %%
model=Sequential()
model.add(Input(shape=(240,240,3)))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(16,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(8,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 238, 238, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 119, 119, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 117, 117, 16)   │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 58, 58, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 8)      │         1,160 │
# ...

# %%
model.fit(train, epochs=30, validation_data=vaild)
# Out:
# Epoch 1/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 63s 582ms/step - accuracy: 0.6208 - loss: 0.9877 - val_accuracy: 0.6116 - val_loss: 0.9827
# Epoch 2/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 63s 581ms/step - accuracy: 0.6460 - loss: 0.9302 - val_accuracy: 0.6128 - val_loss: 0.9568
# Epoch 3/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 64s 586ms/step - accuracy: 0.6483 - loss: 0.9195 - val_accuracy: 0.6081 - val_loss: 0.9660
# Epoch 4/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 64s 590ms/step - accuracy: 0.6446 - loss: 0.9395 - val_accuracy: 0.6174 - val_loss: 0.9771
# Epoch 5/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 64s 588ms/step - accuracy: 0.6235 - loss: 0.9585 - val_accuracy: 0.6512 - val_loss: 0.8639
# Epoch 6/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 64s 589ms/step - accuracy: 0.6541 - loss: 0.8869 - val_accuracy: 0.6419 - val_loss: 0.8953
# Epoch 7/30
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 64s 586ms/step - accuracy: 0.6732 - loss: 0.8400 - val_accuracy: 0.6500 - val_loss: 0.8762
# Epoch 8/30
# ...
